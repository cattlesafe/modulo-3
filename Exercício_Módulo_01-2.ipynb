# %% [markdown]
# **Exercício Módulo 01**

# %%
# Input de dados
valor01 = input('Digite o valor [01]: ')
valor02 = input('Digite o valor [02]: ')

# Variável para guardar a operação
calculo = input('Digite a operação (+, -, /, *): ')

# Condicional para retornar a operação escolhida
if calculo == '+':
  resultado = int(valor01) + int(valor02)
elif calculo == '-':
  resultado = int(valor01) - int(valor02)
elif calculo == '/':
  resultado = int(valor01) / int(valor02)
elif calculo == '*':
  resultado = int(valor01) * int(valor02)
else:
    resultado = 'Operação inválida'

# Imprimir o resultado para o usuário
print('O valor cálculado é: ', resultado)
# Out:
# Digite o valor [01]: 10
# Digite o valor [02]: 20
# Digite a operação (+, -, /, *): +
# O valor cálculado é:  30
